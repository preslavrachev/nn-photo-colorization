# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import colorizer_ab_quantization as cl
from keras.models import model_from_json

# %%
# %ls results
# Out:
# 1000_iters_no_weighting/
# 22052018_1000_iters_13_imgs_128_weighting/
# 22052018_2000_iters_14_imgs_128_weighting/
# 22052018_3000_iters_15_imgs_128_weighting/
# results/

# %%
model_dir = '22052018_1000_iters_13_imgs_128_weighting'
json_file = open('results/' + model_dir + '/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

model = model_from_json(loaded_model_json)

model.load_weights('results/' + model_dir + '/weights_dump.h5')

# %%
image = cl.load_and_resize_image('images/regensburg.jpg', target_size=(512, 512))
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x11D75F0B8>

# %%
X,Y = cl.turn_image_into_input_and_output(image)

# %%
cl.colorize_image(X=X, model=model, name='output.jpg')
